# %% [markdown]
# # Team Rocket
#
# <div style="width:100%; margin: auto;">
#
# [![no internet?](https://www.pokemon.com/static-assets/content-assets/cms2/img/watch-pokemon-tv/seasons/season16/season16_ep42_ss04.jpg)](link_url)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('typeracer.csv')
data.isnull().sum()
data
data.describe()
# Out:
#            Race #       Text ID         WPM    Accuracy      Points  \
# count  999.000000  9.990000e+02  999.000000  999.000000  999.000000
# mean   500.000000  2.980849e+06   85.079413    0.971977   75.550359
# std    288.530761  1.999643e+06   10.312869    0.011982   28.904987
# min      1.000000  7.200000e+01   39.210823    0.927765   13.171462
# 25%    250.500000  7.230000e+02   78.892273    0.963749   55.702456
# 50%    500.000000  3.622435e+06   85.351944    0.973118   70.455354
# 75%    749.500000  4.265459e+06   92.259087    0.980263   91.621763
# max    999.000000  5.390567e+06  116.453461    1.000000  222.162730
#
#              Rank    # Racers
# count  999.000000  999.000000
# mean     2.297297    4.448448
# std      1.102331    0.818802
# min      1.000000    1.000000
# 25%      1.000000    4.000000
# 50%      2.000000    5.000000
# 75%      3.000000    5.000000
# max      5.000000    5.000000

# %% [markdown]
# #Three questions
#
# ## WPM over time
# ## WPM and accuracy correlation
# ## Time of day vs accuracy or wpm

# %%
# sns uses the column names as axis names, which isnt always great
# you can override this by specifying the axis names

sns.scatterplot(data=data, x='WPM', y='Accuracy', hue= 'Rank')
plt.xlabel('WPM')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
