# %% [markdown]
# # Day 6 EOD: Sixty-Four Contests, Two Tables
#
# Date: 09/08/2026

# %%
import pandas as pd

url = 'https://eds-217-essential-python.github.io/data/eurovision_contestants.csv'
eurovision = pd.read_csv(url)

# %%
# how many rows and columns?
eurovision.shape

# how many nulls in the df?
eurovision.isnull().sum()

# how many null rows per year in the points_final col?
eurovision.groupby('year')['points_final'].count()

contests = eurovision[eurovision['year'] != 2020].copy()
contests

contests['decade'] = (((contests['year']/10).astype(int))*10)
contests['decade'].value_counts()

contests[(contests['year'] > 2000) & (contests[''])]
# Out:
# decade
# 2010    408
# 2000    336
# 1990    236
# 1980    200
# 1970    176
# 1960    163
# 1950     43
# Name: count, dtype: int64

# %%
fullyears[(fullyears['year'] > 1959) & ()]
