# %% [markdown]
# # Day 2 EOD: A Data Biography of Toolik Field Station Weather
#
# Date: 09/01/2026

# %%
import pandas as pd
data = pd.read_csv('https://eds-217-essential-python.github.io/data/toolik_weather.csv')

# %% [markdown]
# The df has 11171 rows and 21 columns
# column names are listed below
# data typpes are listed below
# beginning of data set is 19880601
# end of data set is 20181231

# %%
data
list(data.columns)
data.dtypes
data['Date'].min()
data['Date'].max()
# Out:
# 20181231

# %% [markdown]
# all columns other than the first 5 have null values somewhere inside them
#
# flag daily windspeed, flag global rad, and flag air temp have the most null values
#
# flag daily winspeed is missing all values except 1
#
# flag columns might be summary statistics like means and sums

# %%
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11171 entries, 0 to 11170
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             11171 non-null  int64
#  1   Month                            11171 non-null  int64
#  2   Date                             11171 non-null  int64
#  3   LTER_Site                        11171 non-null  object
#  4   Station                          11171 non-null  object
#  5   Daily_AirTemp_Mean_C             11171 non-null  float64
#  6   Flag_Daily_AirTemp_Mean_C        1310 non-null   object
#  7   Daily_AirTemp_AbsMax_C           11001 non-null  float64
#  8   Flag_Daily_AirTemp_AbsMax_C      1020 non-null   object
#  9   Daily_AirTemp_AbsMin_C           10967 non-null  float64
#  10  Flag_Daily_AirTemp_AbsMin_C      1236 non-null   object
#  11  Daily_Precip_Total_mm            10751 non-null  float64
# ...

# %% [markdown]
# There is only one site and one station in this data set: Arc and Tlkmain.
#
# There is only one value in the flag_daily_airtemp_mean_C column, and it's E.
#
# Most years have data for every day of the year, but some have 1 extra and 1 has only ~half a year

# %%
data['LTER_Site'].value_counts()
data['Station'].value_counts()
data['Flag_Daily_AirTemp_Mean_C'].value_counts()
data['Year'].unique()
data['Year'].value_counts().tail()
# Out:
# Year
# 2011    365
# 2017    365
# 2015    365
# 2018    365
# 1988    214
# Name: count, dtype: int64

# %% [markdown]
# mean daily air temp: -8.2C
#     min: -55.60
#     max: 20.70
#     seems like a normal range of temps to me but i never been there
#
# Daily precip mean: 0.95
#     min:0
#     max:64.5
#     eh looks mostly fine to me

# %%
data.describe()
# Out:
#                Year         Month          Date  Daily_AirTemp_Mean_C  \
# count  11171.000000  11171.000000  1.117100e+04          11171.000000
# mean    2003.203384      6.570674  2.003271e+07             -8.196437
# std        8.831548      3.443637  8.830795e+04             14.831314
# min     1988.000000      1.000000  1.988060e+07            -55.600000
# 25%     1996.000000      4.000000  1.996012e+07            -19.700000
# 50%     2003.000000      7.000000  2.003092e+07             -7.100000
# 75%     2011.000000     10.000000  2.011051e+07              4.400000
# max     2018.000000     12.000000  2.018123e+07             20.700000
#
#        Daily_AirTemp_AbsMax_C  Daily_AirTemp_AbsMin_C  Daily_Precip_Total_mm  \
# count            11001.000000            10967.000000           10751.000000
# mean                -3.447132              -13.295924               0.950953
# std                 14.805298               14.727318               2.749060
# ...

# %%
data.columns
keep = ['Year','Date','Daily_AirTemp_AbsMin_C','Flag_Daily_AirTemp_AbsMin_C','Station']
newdata = data[keep]
dict = {'Year':'yea','Date':'dat'}
newdatarename = newdata.rename(columns=dict)
newdatarename
# Out:
#         yea       dat  Daily_AirTemp_AbsMin_C  \
# 0      1988  19880601                     NaN
# 1      1988  19880602                     NaN
# 2      1988  19880603                     NaN
# 3      1988  19880604                     NaN
# 4      1988  19880605                     NaN
# ...     ...       ...                     ...
# 11166  2018  20181227                   -26.7
# 11167  2018  20181228                   -26.3
# 11168  2018  20181229                   -25.8
# 11169  2018  20181230                   -28.0
# 11170  2018  20181231                    -7.9
#
#       Flag_Daily_AirTemp_AbsMin_C  Station
# 0                             NaN  TLKMAIN
# 1                             NaN  TLKMAIN
# 2                             NaN  TLKMAIN
# 3                             NaN  TLKMAIN
# 4                             NaN  TLKMAIN
# ...                           ...      ...
# 11166                         NaN  TLKMAIN
# 11167                         NaN  TLKMAIN
# ...

# %% [markdown]
# The data set is a bunch of measurements from online from a station named tulik or something and, for the most part, they are taking data once a day every day of the year from 1988 to another date.
#
# There are something like 11171 rows and something like 15 cols.
#
# The condition is basically good, things look nice not lots of null values except for in the flag columns but that might be by design. Two things people should know is that for some years there are 366 data poitns and the flag columsn are mostly unpopulated.
#
# Yes i think you could use it to talk about changing summer temps but you would have to filter out some data and double check that there arent any sneaky weird numbers in there.
