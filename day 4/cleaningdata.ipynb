# %%
import pandas as pd

url = 'https://eds-217-essential-python.github.io/data/marine_microplastics.csv'
plastics = pd.read_csv(url)
plastics.shape
# Out:
# ---------------------------------------------------------------------------
#
# ConnectionResetError                      Traceback (most recent call last)
#
# Cell In[1], line 4
#
#       1 import pandas as pd
#
#       3 url = 'https://eds-217-essential-python.github.io/data/marine_microplastics.csv'
#
# ----> 4 plastics = pd.read_csv(url)
#
#       5 plastics.shape
#
#
#
# ...
