# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://eds-217-essential-python.github.io/data/toolik_weather.csv"
df = pd.read_csv(url)

yearly = df.groupby('Year')
yearlymeans = monthly['Daily_Precip_Total_mm'].mean()
yearlymeans

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.bar(months, monthly_means)
plt.title("Toolik Monthly Temperatures")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# File /opt/miniforge3/envs/eds217/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2523, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#
#    2522 try:
#
# -> 2523     x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#
#    2524         # Make args iterable too.
#
#    2525         np.atleast_1d(x), height, width, y, linewidth, hatch
#
#    2526     )
#
#    2527 except ValueError as e:
#
#
#
# File /opt/miniforge3/envs/eds217/lib/python3.11/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
#
# --> 540 shape = _broadcast_shape(*args)
#
#     542 if all(array.shape == shape for array in args):
#
#     543     # Common case where nothing needs to be broadcasted.
#
#
#
# ...
